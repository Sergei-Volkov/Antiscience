# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(0, 'C:/Users/Admin/Desktop/Antiscience/code')

# %% [markdown]
# **Как известно, наш мир - это компьютерная симуляция, написанная много лет назад начинающей командой разработчиков. В коде этой программы по-прежнему находят многочисленные баги. Некоторые из них настолько серьезные, что пофиксить их пока не удалось никому.**
#
# **Так например иногда разработчики находят недочеты в системе взаимодействия между пользователями. И который раз уже работу над этими вопросами поручают Лупе и Пупе в надежде на то, что они смогут сделать все нормально... Вот и недавно на тестовом сервере они должны были выпустить пробную версию ивента, в котором нужно избегать других пользователей. Но на проде все перепутали, и Лупа получил ___ за Пупу, а Пупа залил все на глобальный сервер...**

# %%
import world

# %%
world.create()
# Out:
# Создание континентов:: 100%|█████████████████████████████████████████████████████████████████████| 7/7 [00:00<?, ?it/s]
# Создание городов:: 100%|████████████████████████████████████████████████| 2700000/2700000 [00:01<00:00, 2023608.45it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-3-2700bc1a9efd> in <module>
# ----> 1 world.create()
#
# C:/Users/Admin/Desktop/Antiscience/code\world.py in create()
#       6     for _ in tqdm(np.arange(2.7e6), desc='Создание городов:'):
#       7         pass
# ----> 8     for i in tqdm(np.arange(10e9), desc='Обновление базы данных '
#       9                                         'пользователей:'):
#      10         try:
#
# MemoryError: Unable to allocate 74.5 GiB for an array with shape (10000000000,) and data type float64

# %%
world.NPC(7.5e9)  # типа что-то много NPC, симуляция пытается сократить их число
# Out:
# Неверное количество NPC

# %% [markdown]
# **Результаты такого косяка не заставили себя ждать. Довольно скоро стали поступать многочисленные запросы от пользователей содержания:**
#
# "Перезапустите год!!! у меня вирус..." и "SMTH ELSE"
#
# **Увы, простые советы перезапустить программу были отвергнуты пользователями в штыки. Поэтому остальной части команды разработчиков как всегда пришлось отдуваться за Лупу и Пупу и в срочном порядке выпускать патч для стабилизации ситуации.**

# %% [markdown]
# # Добавить мемные картиночки для каждого из пунктов !!!

# %% [markdown]
# ## Патч №1.4.8.8 версия 80dol(lar) от 15.03, кодовое название "Самоизоляция"
# Список фиксов:
#
# * Ограничен доступ к локации "Улица": в этой версии патча она доступна только в случае необходимости доступа к зонам "Ближайший магазин", "Ближайшая аптека" и "Работа", а также при наличии NPC "Собака".
#
# * Все локации, в которые можно попасть через зону "Улица", заблокированы на неопределенный срок. При попытке попасть в запрещенную зону будет высвечиваться информационное окно с сообщением **"Эта зона еще не разблокирована."**, возможно появление NPC "Полиция" и включение модуля "Штрафы".
#
# * Добавлена опция ношения защиты типа "Маска" в локациях, доступных различным пользователям.
#
# * Была добавлены инструменты "Удаленное общение" и "Дистанционная работа/обучение" # **картинка "УдАленка"** #. На момент выпуска патча эти опции не до конца отлажены, следите за обновлениями.
#
# * Были пополнены запасы ресурсов "Туалетная бумага" и "Гречка" части пользователей.
#
# UPD от 15.04:
#
# * Для использования инструментов "Автомобиль" и "Велосипед" пользователям нужно указать цель их использования в соответствующем окне, всплывающем при попытке их использования.

# %% [markdown]
# ## Опрос пользователей???
